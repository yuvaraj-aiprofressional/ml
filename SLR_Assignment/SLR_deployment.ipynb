# %%
#To import python libraries - Pickle & Pandas
import pickle
import pandas as PD
#Load the saved model file in read mode to predict the user input.
result = pickle.load(open("resultModel.sav",'rb')).predict(PD.DataFrame({'YearsExperience':[20]}))
#Print the response / result.
result
# Out:
# array([[213982.61706507]])
