# %%
import pandas as pd #importing pandas library

# %%
df = pd.read_csv('insurance_pre.csv') #loading data to the dataset
df.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
df.shape #checking the shape of dataframe
# Out:
# (1338, 6)

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset = pd.get_dummies(dataset,drop_first=True).astype(int)
dataset.head(3)
# Out:
#    age  bmi  children  charges  sex_male  smoker_yes
# 0   19   27         0    16884         0           1
# 1   18   33         1     1725         1           0
# 2   28   33         3     4449         1           0

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.3,random_state = 3)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators=50,random_state=0,criterion='absolute_error',max_features=None)
regressor.fit(X_train,y_train)
# Out:
# C:\Users\abin.k\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(criterion='absolute_error', max_features=None,
#                       n_estimators=50, random_state=0)

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_square = r2_score(y_test,y_pred)
r_square
# Out:
# 0.8409143724264692

# %%
import pickle

# %%
filename = 'finalized_model_RandomForest.sav'
pickle.dump(regressor,open(filename,'wb'))

# %%
saved_model = pickle.load(open('finalized_model_RandomForest.sav','rb'))

# %%
res=saved_model.predict([[28,27,0,1,0]])
res
# Out:
# C:\Users\abin.k\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([4037.14])
