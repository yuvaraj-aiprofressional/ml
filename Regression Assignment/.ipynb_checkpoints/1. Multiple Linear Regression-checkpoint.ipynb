# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %% [markdown]
# dataset.columns

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
indep
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
dep
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %% [markdown]
# # X_train

# %%
X_train.shape
# Out:
# (892, 5)

# %%
y_train
# Out:
#       charges
# 482      1622
# 338     41919
# 356      8944
# 869      4391
# 182      4005
# ...       ...
# 763      3070
# 835      7160
# 1216     5415
# 559      1646
# 684      4766
#
# [892 rows x 1 columns]

# %%
y_train.shape
# Out:
# (892, 1)

# %% [markdown]
# # X_test

# %%
X_test.shape
# Out:
# (446, 5)

# %%
y_test
# Out:
#       charges
# 578      9724
# 610      8547
# 569     45702
# 1034    12950
# 198      9644
# ...       ...
# 261     17085
# 1271     3021
# 1313    36397
# 2        4449
# 405     11396
#
# [446 rows x 1 columns]

# %%
y_test.shape
# Out:
# (446, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)#y=W*x1+b0 for this equation we got value for b1 and bo
# Out:
# LinearRegression()

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html

# %%
from sklearn.metrics import r2_score
y_pred = regressor.predict(X_test)
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.7862502913924561

# %%
import pickle

# %%
pickle.dump(regressor,open("multiple_linear_model.sav","wb"))

# %%
model=pickle.load(open("multiple_linear_model.sav","rb"))

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
# cols_to_convert = ['age', 'bmi', 'children',  'sex_male', 'smoker_yes']
# indep[cols_to_convert] = indep[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
age_input=int(input("Age"))
bmi_input=int(input("BMI"))
children_input=int(input("Children"))
sex_input=int(input("sex Male - True or False"))
smoker_input=int(input("Smoker Yes - True or False"))
# Out:
# Age 29
# BMI 30
# Children 0
# sex Male - True or False 1
# Smoker Yes - True or False 0

# %%
indep.dtypes
# Out:
# age           int64
# bmi           int64
# children      int64
# sex_male      int64
# smoker_yes    int64
# dtype: object

# %%
result=model.predict([[age_input,bmi_input,children_input,sex_input,smoker_input]])
# Out:
# C:\Users\YUVARAJ.R\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[5062.48288841]])
